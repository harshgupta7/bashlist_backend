# %%
from plots.notif_plots import plots
from plots.pr_text_plots import prplots
from plots.pr_plots import pr_plot
from plots.success_rate import risk
from plots.user_plots import users

# %% [markdown]
# # Total Notification Share
#
# Represents share of notifications sent by risk type.

# %%
plot = plots('queries/pr_read_notread.sql')
plot.notification_share()

# %% [markdown]
# # Percentage Read
#
# Shows what fraction of Notifications are read for every individual risk type.

# %%
plot.readornot()

# %% [markdown]
# # Share of Reads
#
# This shows the percentage of each individual risk type in the total number of read notifications, thus displaying the distribution of the notifications that users read.
#
# For eg. In this graph, if BigDiff has a value of 20, this means that if a user has read 500 notifications in total, 100 of them were bigdiff.

# %%
plot.read_share()

# %% [markdown]
# # Average Notification Text
#
# This is equal to the PR title. Plots title size vs probability.
# eg. (4,0.10) in (x,y) format means that there is a 10% chance that a PR will have title size of 4.

# %%
pr_plot = prplots()

# %%
# Warning: This is a computationally heavy process, may take 15-20s to run.
pr_plot.title_size_dist()

# %% [markdown]
# # Risk Presence Count
#
# Shows the number of PRs with the particular risk.
# Note: One PR can have more than one type of risk.

# %%
plot = risk()
plot.plot_risk_presence_count()
# Out:
# Total PRs with atleast one risk : 49333
# Total PRs:1288358

# %% [markdown]
# # Risk Presence Probability
# Shows the probability of a risk being present in any PR.
#
# Note:
#
# 1. A risk might be present in more than one PR
#
# 2. Only PRs after 29 December 2017 are included, as that is when first PR risk is flagged.

# %%
plot.plot_risk_presence_distribution()

# %% [markdown]
# # Risk Type and PR State
#
# Plots the distribution of the state of PR with the given risk type.

# %%
plot.plot_state_percentage()

# %% [markdown]
# # Number of Risks In a PR
# Plots the probability of number of risks in a PR. Eg. (3,2.5) means that there is a 2.5% chance that a given PR will have 3 risks.

# %%
plot.plot_num_risks()

# %% [markdown]
# # Number of PRs Analyzed
# Number of PRs analyzed daily.
# * Excludes business holidays and weekends.
# * Green line denotes mean.

# %%
prp = pr_plot()
prp.plot_num_prs()

# %% [markdown]
# # User Signups Over Time
# * Monthly signups
# * Green line denotes mean.

# %%
userp = users()
userp.user_signup_monthly()
